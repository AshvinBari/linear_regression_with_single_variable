# %%
import pandas as pd 
import seaborn as sns
from sklearn import linear_model

# %%
#df=pd.read_csv('Insurance.csv')
df=pd.read_csv(r'C:\Users\hp\OneDrive\Desktop\Insurance.csv')
# read file of two types

# %%
df
# Out:
#    Age  premium
# 0   20    15000
# 1   30    35200
# 2   35    40000
# 3   40    50000
# 4   45    60000
# 5   50    75400

# %%
sns.lmplot(x='Age',y='premium',data=df)
#best fit line

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['Age']],df['premium'])
# call the linearRegression method
# Out:
# LinearRegression()

# %%
reg.predict([[42]])

#this is prediction value
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([56179.42857143])

# %%
reg.predict([[73]])
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([115734.85714286])

# %% [markdown]
# reg.coef_
# #y=mx+c
# #coefficient

# %%
#Intercept
reg.intercept_
# Out:
# -24508.571428571413

# %% [markdown]
# #validating our Model
#
# #linear equation y=mx=c
# #premium=m*age+c
